# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('humidity_data.csv')

# %%
df.head()
# Out:
#    Month  Hour  windSpeed    Water  Wind dir  Pressure  Temperature     RH
# 0    2.0   3.0       4.75  0.09330      45.0    976.35        34.56  39.70
# 1    2.0   4.0       3.80  0.09290      73.0    976.15        34.51  39.55
# 2    2.0   5.0       3.60  0.09215     108.0    976.45        34.05  37.90
# 3    2.0   6.0       2.30  0.09145     126.5    976.90        31.61  41.90
# 4    2.0   7.0       3.80  0.09040     136.0    977.75        30.47  44.50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17088 entries, 0 to 17087
# Data columns (total 8 columns):
# Month          17088 non-null float64
# Hour           17088 non-null float64
# windSpeed      17088 non-null float64
# Water          17088 non-null float64
# Wind dir       17088 non-null float64
# Pressure       17088 non-null float64
# Temperature    17088 non-null float64
# RH             17088 non-null float64
# dtypes: float64(8)
# memory usage: 1.0 MB

# %%
df.isnull().sum()
# Out:
# Month          0
# Hour           0
# windSpeed      0
# Water          0
# Wind dir       0
# Pressure       0
# Temperature    0
# RH             0
# dtype: int64

# %%
features = df.drop(['Month','Hour'],axis=1)

# %%
features.head()
# Out:
#    windSpeed    Water  Wind dir  Pressure  Temperature     RH
# 0       4.75  0.09330      45.0    976.35        34.56  39.70
# 1       3.80  0.09290      73.0    976.15        34.51  39.55
# 2       3.60  0.09215     108.0    976.45        34.05  37.90
# 3       2.30  0.09145     126.5    976.90        31.61  41.90
# 4       3.80  0.09040     136.0    977.75        30.47  44.50

# %%
correlation=features.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation,vmax=1,square=True,annot=True,cmap='viridis')
plt.title('Correlation between climate parameters')
# Out:
# Text(0.5, 1, 'Correlation between climate parameters')

# %%
data = pd.read_csv('humid_data.csv',parse_dates=['Period'],index_col='Period')

# %%
data.head()
# Out:
#                      windSpeed    Water  Wind dir  Pressure  Temperature  \
# Period
# 2017-02-16 03:30:00       4.75  0.09330      45.0    976.35        34.56
# 2017-02-16 04:30:00       3.80  0.09290      73.0    976.15        34.51
# 2017-02-16 05:30:00       3.60  0.09215     108.0    976.45        34.05
# 2017-02-16 06:30:00       2.30  0.09145     126.5    976.90        31.61
# 2017-02-16 07:30:00       3.80  0.09040     136.0    977.75        30.47
#
#                         RH
# Period
# 2017-02-16 03:30:00  39.70
# 2017-02-16 04:30:00  39.55
# 2017-02-16 05:30:00  37.90
# 2017-02-16 06:30:00  41.90
# 2017-02-16 07:30:00  44.50

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17088 entries, 2017-02-16 03:30:00 to 2019-04-28 07:30:00
# Data columns (total 6 columns):
# windSpeed      17088 non-null float64
# Water          17088 non-null float64
# Wind dir       17088 non-null float64
# Pressure       17088 non-null float64
# Temperature    17088 non-null float64
# RH             17088 non-null float64
# dtypes: float64(6)
# memory usage: 934.5 KB

# %%
data['2017'].Temperature.resample('M').mean().plot(color='r',label='2017')

# %%
data['2018'].Temperature.resample('M').mean().plot()

# %%
data['2019'].Temperature.resample('M').mean().plot()

# %%
data['2019'].RH.resample('M').mean().plot()

# %%
data['2018'].RH.resample('M').mean().plot()

# %%
data['2017'].RH.resample('M').mean().plot()

# %%
data['2019'].Temperature.plot()

# %%
data['2017'].RH.plot()

# %%
data['2018'].RH.plot()

# %%
hack_data = data.reset_index()

# %%
hack_data.head()
# Out:
#                Period  windSpeed    Water  Wind dir  Pressure  Temperature  \
# 0 2017-02-16 03:30:00       4.75  0.09330      45.0    976.35        34.56
# 1 2017-02-16 04:30:00       3.80  0.09290      73.0    976.15        34.51
# 2 2017-02-16 05:30:00       3.60  0.09215     108.0    976.45        34.05
# 3 2017-02-16 06:30:00       2.30  0.09145     126.5    976.90        31.61
# 4 2017-02-16 07:30:00       3.80  0.09040     136.0    977.75        30.47
#
#       RH
# 0  39.70
# 1  39.55
# 2  37.90
# 3  41.90
# 4  44.50

# %%
df2 = hack_data.set_index('Period')

# %%
df2.head()
# Out:
#                      windSpeed    Water  Wind dir  Pressure  Temperature  \
# Period
# 2017-02-16 03:30:00       4.75  0.09330      45.0    976.35        34.56
# 2017-02-16 04:30:00       3.80  0.09290      73.0    976.15        34.51
# 2017-02-16 05:30:00       3.60  0.09215     108.0    976.45        34.05
# 2017-02-16 06:30:00       2.30  0.09145     126.5    976.90        31.61
# 2017-02-16 07:30:00       3.80  0.09040     136.0    977.75        30.47
#
#                         RH
# Period
# 2017-02-16 03:30:00  39.70
# 2017-02-16 04:30:00  39.55
# 2017-02-16 05:30:00  37.90
# 2017-02-16 06:30:00  41.90
# 2017-02-16 07:30:00  44.50

# %%
df2.isnull().sum()
# Out:
# windSpeed      0
# Water          0
# Wind dir       0
# Pressure       0
# Temperature    0
# RH             0
# dtype: int64

# %%
df2['Month'] = df2.index.month
df2['Day'] = df2.index.day
df2['Hour']= df2.index.hour

# %%
df2.head()
# Out:
#                      windSpeed    Water  Wind dir  Pressure  Temperature  \
# Period
# 2017-02-16 03:30:00       4.75  0.09330      45.0    976.35        34.56
# 2017-02-16 04:30:00       3.80  0.09290      73.0    976.15        34.51
# 2017-02-16 05:30:00       3.60  0.09215     108.0    976.45        34.05
# 2017-02-16 06:30:00       2.30  0.09145     126.5    976.90        31.61
# 2017-02-16 07:30:00       3.80  0.09040     136.0    977.75        30.47
#
#                         RH  Month  Day  Hour
# Period
# 2017-02-16 03:30:00  39.70      2   16     3
# 2017-02-16 04:30:00  39.55      2   16     4
# 2017-02-16 05:30:00  37.90      2   16     5
# 2017-02-16 06:30:00  41.90      2   16     6
# 2017-02-16 07:30:00  44.50      2   16     7

# %%
data['2017'].RH.resample('H').mean().plot(color='r',label='2017')
#data['2018'].RH.resample('D').mean().plot(color='g',label='2018')
#data['2019'].RH.resample('D').mean().plot(color='b',label='2019')

# %%
data['2018'].RH.resample('H').mean().plot(color='g',label='2018')

# %%
hack_data.drop(['windSpeed','Water','Wind dir','Pressure','Temperature'],axis=1,inplace=True)

# %%
hack_data.head()
# Out:
#                Period     RH
# 0 2017-02-16 03:30:00  39.70
# 1 2017-02-16 04:30:00  39.55
# 2 2017-02-16 05:30:00  37.90
# 3 2017-02-16 06:30:00  41.90
# 4 2017-02-16 07:30:00  44.50

# %%
hack_data.describe()
# Out:
#                  RH
# count  17088.000000
# mean      77.368440
# std       19.435437
# min       11.300000
# 25%       67.400000
# 50%       83.050000
# 75%       92.900000
# max      100.000000

# %%
hack_data.to_csv('timeweather.csv',header=True,index=False)

# %%
time_data=hack_data.set_index('Period')

# %%
time_data.head()
# Out:
#                         RH
# Period
# 2017-02-16 03:30:00  39.70
# 2017-02-16 04:30:00  39.55
# 2017-02-16 05:30:00  37.90
# 2017-02-16 06:30:00  41.90
# 2017-02-16 07:30:00  44.50

# %%
time_data_mean = time_data['2019'].rolling(window=100).mean()

# %%
time_data_mean.plot()

# %%
time_data_mean18 = time_data['2018'].rolling(window=100).mean()

# %%
time_data_mean18.plot()

# %%
time_data_mean17 = time_data['2017'].rolling(window=100).mean()

# %%
time_data_mean17.plot()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
plot_acf(time_data)

# %%
plot_pacf(time_data)

# %%
train_size = int(len(time_data)*0.8)
test_size = len(time_data)-train_size
train,test = time_data.iloc[0:train_size],time_data.iloc[train_size:len(time_data)]
print(train.shape,test.shape)
# Out:
# (13670, 1) (3418, 1)

# %%
def create_dataset(dataset,time_step=1):
    dataX,dataY = [],[]
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step),0]
        dataX.append(a)
        dataY.append(dataset[i+time_step,0])
    return np.array(dataX),np.array(dataY)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
train = scaler.fit_transform(train)
test = scaler.fit_transform(test)

# %%
time_step=3
trainX,trainY=create_dataset(train,time_step)
testX,testY=create_dataset(train,time_step)

# %%
trainX = np.reshape(trainX,(trainX.shape[0],1,trainX.shape[1]))

# %%
from keras.models import Sequential
from keras.layers import Dense,LSTM
from sklearn.metrics import mean_squared_error
import math

# %%
model = Sequential()
model.add(LSTM(4,input_shape=(1,time_step)))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.fit(trainX,trainY,epochs=50,batch_size=32)
# Out:
# Epoch 1/50
# 428/428 [==============================] - 1s 3ms/step - loss: 0.2501
# Epoch 2/50
# 428/428 [==============================] - 3s 8ms/step - loss: 0.0126
# Epoch 3/50
# 428/428 [==============================] - 1s 3ms/step - loss: 0.0097
# Epoch 4/50
# 428/428 [==============================] - 3s 7ms/step - loss: 0.0070
# Epoch 5/50
# 428/428 [==============================] - 1s 3ms/step - loss: 0.0054
# Epoch 6/50
# 428/428 [==============================] - 1s 3ms/step - loss: 0.0045
# Epoch 7/50
# 428/428 [==============================] - 3s 7ms/step - loss: 0.0038
# Epoch 8/50
# 428/428 [==============================] - 1s 3ms/step - loss: 0.0031
# Epoch 9/50
# 428/428 [==============================] - 1s 3ms/step - loss: 0.0025
# Epoch 10/50
# 428/428 [==============================] - 3s 7ms/step - loss: 0.0020
# Epoch 11/50
# 428/428 [==============================] - 2s 4ms/step - loss: 0.0017
# Epoch 12/50
# ...

# %%
testX = np.reshape(testX,(testX.shape[0],1,testX.shape[1]))

# %%
#make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# %%
#invert Prediction
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %%
#Calculate root mean Squared error
trainscore=math.sqrt(mean_squared_error(trainY[0],trainPredict[:,0]))
print('Train Score: %.2f RMSE' %(trainscore))
testscore=math.sqrt(mean_squared_error(testY[0],testPredict[:,0]))
print('test Score: %.2f RMSE' %(testscore))
# Out:
# Train Score: 3.11 RMSE
# test Score: 3.11 RMSE

# %%
#shift train prediction for plotting
trainPredictPlot = np.empty_like(time_data)
trainPredictPlot[:,:]=np.nan
trainPredictPlot[time_step:len(trainPredict)+time_step,:]=trainPredict
#shift test prediction for plotting
testPredictPlot = np.empty_like(time_data)
testPredictPlot[:,:]=np.nan
testPredictPlot[len(trainPredict)+(time_step*2)+1:len(time_data)-1,:]=testPredict
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-13787d9e4465> in <module>
#       6 testPredictPlot = np.empty_like(time_data)
#       7 testPredictPlot[:,:]=np.nan
# ----> 8 testPredictPlot[len(trainPredict)+(time_step*2)+1:len(time_data)-1,:]=testPredict
#
# ValueError: could not broadcast input array from shape (13666,1) into shape (3414,1)

# %%
plt.plot(testY.flatten(),marker='.',label=True)
plt.plot(testPredict.flatten(),color='r',label='predicted')
plt.title('Predicted values and the Actual Values')
plt.legend()
